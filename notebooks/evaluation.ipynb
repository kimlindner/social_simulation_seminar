# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load test csv
stats = pd.read_csv('../social_simulation_seminar/models/test_1.csv')
stats
# Out:
#          id        income  income-group       wtp  parking-offender?  \
# 0      1111  20066.710090             1  4.103842              False
# 1      1209  20949.733322             1  5.155666              False
# 2      1273  26061.313582             1  3.688823              False
# 3      1072  14662.453614             0  3.105921              False
# 4      1374  36403.669318             1  3.693789              False
# ...     ...           ...           ...       ...                ...
# 8765   9925  16499.689924             0  1.912904              False
# 8766  10044   8007.896823             0  1.317967              False
# 8767   9982  45728.092290             1  4.166482              False
# 8768  10099  28316.514499             1  2.110176              False
# 8769   9866   7423.301732             0  1.352993              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
stats.nunique()
# Out:
# id                         8770
# income                     8770
# income-group                  3
# wtp                        8770
# parking-offender?             2
# distance-parking-target     181
# price-paid                   14
# search-time                 700
# wants-to-park                 2
# die?                          1
# reinitialize?                 1
# utility-value              8770
# mean-utility               5577
# informed-flag                 2
# agent-strategy-flag           7
# wait-time                     1
# park-time                  8769
# switch-strategy-flag          3
# dtype: int64

# %%
stats = stats.dropna()

# %%
stats
# Out:
#          id        income  income-group       wtp  parking-offender?  \
# 0      1111  20066.710090             1  4.103842              False
# 1      1209  20949.733322             1  5.155666              False
# 2      1273  26061.313582             1  3.688823              False
# 3      1072  14662.453614             0  3.105921              False
# 4      1374  36403.669318             1  3.693789              False
# ...     ...           ...           ...       ...                ...
# 8764   9940  14133.032261             0  4.133196              False
# 8765   9925  16499.689924             0  1.912904              False
# 8766  10044   8007.896823             0  1.317967              False
# 8767   9982  45728.092290             1  4.166482              False
# 8768  10099  28316.514499             1  2.110176              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
parked = stats[(stats['wants-to-park']==True) & (stats['price-paid']!= -99)]
parked
# Out:
#         id        income  income-group        wtp  parking-offender?  \
# 579    941  17344.991241             0   4.044502              False
# 785   1146  31126.496166             1   7.842640              False
# 828   1148  58899.402229             2  10.434739              False
# 871   1247  25494.973646             1   3.599662               True
# 1174  1194  19114.287121             1   3.863266              False
# ...    ...           ...           ...        ...                ...
# 8701  1137  43096.175981             1   4.307860               True
# 8707  6003  50964.025547             2  10.600620               True
# 8709   928  28238.562736             1   5.696451              False
# 8746   913  27670.204672             1   5.154197              False
# 8762  1326  31348.161225             1   6.309214               True
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
parked.groupby('income-group').mean()
# Out:
#                        id        income       wtp  parking-offender?  \
# income-group
# 0             1953.948718  14154.490717  2.495536           0.179487
# 1             1953.620968  28822.806576  4.750738           0.266129
# 2             2220.000000  59936.190783  8.323896           0.230769
#
#               distance-parking-target  price-paid  search-time  wants-to-park  \
# income-group
# 0                           13.398454    3.641026   684.538462            1.0
# 1                           18.232029    3.669355   541.532258            1.0
# 2                           23.343622    4.115385   509.384615            1.0
#
#               die?  reinitialize?  utility-value  mean-utility  informed-flag  \
# income-group
# 0              1.0            1.0      -0.124568     -0.239121       0.538462
# 1              1.0            1.0      -0.133593     -0.235068       0.532258
# 2              1.0            1.0      -0.112386     -0.236227       0.461538
#
# ...

# %%
stats.groupby(by='income-group').mean('utility-value')
# Out:
#                        id        income       wtp  distance-parking-target  \
# income-group
# 0.0           2338.968519  17278.115924  2.466294               -96.997597
# 1.0           2291.858186  34664.711327  4.517561               -96.641395
# 2.0           2229.471264  69856.093031  7.925942               -99.000000
#
#               price-paid  search-time  utility-value  mean-utility  \
# income-group
# 0.0           -98.064815   194.787037      -0.450350     -0.333203
# 1.0           -97.451156   198.167985      -0.453966     -0.332797
# 2.0           -99.000000   217.689655      -0.436298     -0.336046
#
#               informed-flag  agent-strategy-flag  wait-time    park-time  \
# income-group
# 0.0                0.496296             4.472222   0.000000  6688.894675
# 1.0                0.508825             4.401704   0.002435  6871.454123
# 2.0                0.505747             4.517241   0.000000  6924.545057
#
#               switch-strategy-flag
# income-group
# ...

# %%
ax = sns.barplot(x=x, y=y, data=stats)
ax.set_xlabel('Income Group')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
# Out:
# Text(0.5, 1.0, 'Average Utility per Income Group')

# %%
utility = pd.read_csv('avg_utility_income_class.csv')
utility
# Out:
#          2  High_Utility     1  Mid_Utility     0   Low_Utility
# 0        0     -0.376304     0    -0.431093     0     -0.508641
# 1        1     -0.376304     1    -0.431093     1     -0.508641
# 2        2     -0.376304     2    -0.428960     2     -0.508641
# 3        3     -0.376304     3    -0.428960     3     -0.508641
# 4        4     -0.376304     4    -0.427724     4     -0.508641
# ...    ...           ...   ...          ...   ...           ...
# 2585  2585     -0.276445  2585    -0.288466  2585     -0.383801
# 2586  2586     -0.276445  2586    -0.293044  2586     -0.383801
# 2587  2587     -0.276445  2587    -0.292078  2587     -0.385693
# 2588  2588     -0.276445  2588    -0.292798  2588     -0.387288
# 2589  2589     -0.276445  2589    -0.292507  2589     -0.387288
#
# [2590 rows x 6 columns]

# %%
utility_new = utility.drop(columns=["0","1","2"])

# %%
ax = sns.barplot(data=utility_new)
ax.set_xlabel('Income Group')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
# Out:
# Text(0.5, 1.0, 'Average Utility per Income Group')

# %%
all_stats = pd.read_csv('../social_simulation_seminar/models/test_2.csv')
all_stats
# Out:
#          id        income  income-group       wtp  parking-offender?  \
# 0      1156  20137.004475             1  3.606679              False
# 1      1010  14367.173755             0  2.307360               True
# 2       906  20950.343515             1  3.624336              False
# 3      1170  17685.062598             1  3.883471              False
# 4      1206  14031.965779             0  2.720036              False
# ...     ...           ...           ...       ...                ...
# 8665  10028  36064.589436             1  3.929630               True
# 8666   9820  28637.864605             1  3.654324              False
# 8667  10014  27514.074047             1  4.903850              False
# 8668   9919  20656.204069             1  4.772728              False
# 8669  10040  10101.025087             0  2.580250              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
all_stats = all_stats[(all_stats['wants-to-park']==True) & (all_stats['price-paid']!= -99)]
all_stats
# Out:
#         id        income  Income Group       wtp  parking-offender?  \
# 514   1351  24412.474453             1  6.256948               True
# 710   1224  13849.868806             0  4.683243               True
# 799   1211  13932.478173             0  4.129101              False
# 899    937  22246.354073             1  6.150866               True
# 918   1298  14974.620948             0  1.741076               True
# ...    ...           ...           ...       ...                ...
# 8456  5791  47306.442103             2  8.733572              False
# 8467  1332  17475.916266             0  1.438280              False
# 8489  1157  21250.478285             1  5.138065              False
# 8582  1288  11601.984678             0  2.912906              False
# 8644  1037  23170.204239             1  4.202415              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
all_stats.describe()
# Out:
#                 id        income  Income Group         wtp  \
# count   185.000000    185.000000    185.000000  185.000000
# mean   2220.318919  28679.117780      0.929730    4.723753
# std    1770.887585  11604.493287      0.478258    1.635653
# min     895.000000   7691.640840      0.000000    1.409719
# 25%    1103.000000  20307.096851      1.000000    3.683239
# 50%    1311.000000  26894.673409      1.000000    4.569494
# 75%    2927.000000  34890.089444      1.000000    5.539963
# max    7757.000000  84249.490832      2.000000    9.760493
#
#        distance-parking-target  price-paid  search-time  Avg Utility  \
# count               185.000000  185.000000   185.000000   185.000000
# mean                 17.908431    4.197297   548.902703    -0.147369
# std                  10.431270    2.194885   280.326908     0.145043
# min                   1.414214    2.000000    21.000000    -0.597308
# 25%                  10.630146    2.000000   343.000000    -0.245141
# ...

# %%
strategy = all_stats.groupby('agent-strategy-flag').mean().reset_index()
strategy = strategy.rename(columns = {'agent-strategy-flag':'Strategy', 'utility-value':'Avg Utility'})
strategy
# Out:
#    Strategy           id        income  income-group       wtp  \
# 0       1.0  2495.113636  30701.452706      1.000000  4.789045
# 1       2.0  1868.000000  25522.232810      0.833333  4.193842
# 2       3.0  2579.200000  28475.627262      0.950000  5.153455
# 3       4.0  2018.150000  28505.290961      0.950000  5.252856
# 4       5.0  2371.733333  28833.072993      1.000000  5.287849
# 5       6.0  1966.733333  28093.283293      0.888889  4.377804
# 6       7.0  2359.764706  29760.416196      0.882353  4.592880
#
#    parking-offender?  distance-parking-target  price-paid  search-time  \
# 0           0.295455                15.935103    4.806818   603.477273
# 1           0.125000                12.281925    5.125000   525.833333
# 2           0.150000                16.161029    4.137500   560.300000
# 3           0.350000                18.183581    4.062500   555.000000
# 4           0.133333                18.697404    3.333333   553.333333
# ...

# %%
x = strategy['Strategy']
y = strategy['Avg Utility']
ax = sns.set_palette(palette='Blues')
ax = sns.barplot(x=x, y=y, data=strategy, palette='Blues')
ax.set_xlabel('Strategy')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Strategy')
# Out:
# Text(0.5, 1.0, 'Average Utility per Strategy')

# %%
income_utility = all_stats.groupby('income-group').mean().reset_index()
income_utility = income_utility.rename(columns = {'income-group':'Income Group', 'utility-value':'Avg Utility'})
income_utility
# Out:
#    Income Group           id        income       wtp  parking-offender?  \
# 0             0  1980.250000  14147.850533  2.792465           0.250000
# 1             1  2236.704225  28959.888290  4.760444           0.260563
# 2             2  2513.333333  53146.189147  7.981483           0.200000
#
#    distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# 0                16.595106    4.133929   574.071429            1.0   1.0
# 1                18.116429    4.223592   544.260563            1.0   1.0
# 2                18.390930    4.066667   545.866667            1.0   1.0
#
#    reinitialize?  Avg Utility  mean-utility  informed-flag  \
# 0            1.0    -0.146628     -0.291806       0.892857
# 1            1.0    -0.150753     -0.291003       1.035211
# 2            1.0    -0.116720     -0.298265       1.066667
#
#    agent-strategy-flag  wait-time    park-time  switch-strategy-flag
# 0             4.000000        0.0  3584.912247              0.000000
# ...

# %%
x = income_utility['Income Group']
y = income_utility['Avg Utility']
sns.set_palette(palette='Blues')
ax = sns.barplot(x=x, y=y, data=income_utility, palette = 'Blues')
ax.set_xlabel('Income Group')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
# Out:
# Text(0.5, 1.0, 'Average Utility per Income Group')

# %%
ax = sns.relplot()
x = income_utility['Income Group']
y = income_utility['Avg Utility']
sns.set_palette(palette='Blues')
ax = sns.barplot(x=x, y=y, data=income_utility, palette = 'Blues')
ax.set_xlabel('Income Group')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
# Out:
#         id        income  income-group       wtp  parking-offender?  \
# 514   1351  24412.474453             1  6.256948               True
# 710   1224  13849.868806             0  4.683243               True
# 799   1211  13932.478173             0  4.129101              False
# 899    937  22246.354073             1  6.150866               True
# 918   1298  14974.620948             0  1.741076               True
# ...    ...           ...           ...       ...                ...
# 8456  5791  47306.442103             2  8.733572              False
# 8467  1332  17475.916266             0  1.438280              False
# 8489  1157  21250.478285             1  5.138065              False
# 8582  1288  11601.984678             0  2.912906              False
# 8644  1037  23170.204239             1  4.202415              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
all_stats = all_stats.rename(columns = {'income-group':'Income Group', 'utility-value':'Avg Utility'})
all_stats
# Out:
#          id        income  Income Group       wtp  parking-offender?  \
# 0      1156  20137.004475             1  3.606679              False
# 1      1010  14367.173755             0  2.307360               True
# 2       906  20950.343515             1  3.624336              False
# 3      1170  17685.062598             1  3.883471              False
# 4      1206  14031.965779             0  2.720036              False
# ...     ...           ...           ...       ...                ...
# 8665  10028  36064.589436             1  3.929630               True
# 8666   9820  28637.864605             1  3.654324              False
# 8667  10014  27514.074047             1  4.903850              False
# 8668   9919  20656.204069             1  4.772728              False
# 8669  10040  10101.025087             0  2.580250              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
strategies = all_stats['agent-strategy-flag'].value_counts()
strategies
# Out:
# 1.0    2162
# 6.0    2118
# 4.0    1150
# 3.0    1093
# 7.0     805
# 2.0     775
# 5.0     566
# Name: agent-strategy-flag, dtype: int64

# %%
all = all_stats.groupby('Income Group').mean().reset_index()
all
# Out:
#    Income Group           id        income       wtp  parking-offender?  \
# 0             0  5442.448372  13711.090037  2.488178           0.250698
# 1             1  5479.724251  27843.237561  4.531832           0.251023
# 2             2  4954.966102  58197.717800  7.936101           0.259080
#
#    distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# 0               -96.691960  -97.656860   169.816744       0.019070   1.0
# 1               -95.530457  -96.599844   172.773702       0.028819   1.0
# 2               -94.462030  -95.256659   184.242131       0.038741   1.0
#
#    reinitialize?  Avg Utility  mean-utility  informed-flag  \
# 0            1.0    -0.425243     -0.298497       1.000000
# 1            1.0    -0.395431     -0.297700       0.983625
# 2            1.0    -0.404047     -0.299925       1.041162
#
#    agent-strategy-flag  wait-time    park-time  switch-strategy-flag
# 0             3.772918   0.000000  6944.349020              0.000000
# ...

# %%
all_stats.describe()
# Out:
#                  id         income  Income Group          wtp  \
# count   8670.000000    8670.000000   8670.000000  8670.000000
# mean    5445.483391   25784.677372      0.799654     4.187207
# std     2571.909994   11665.514778      0.505478     1.660785
# min      885.000000    3703.519880      0.000000     0.651949
# 25%     3225.250000   17722.073697      1.000000     3.018168
# 50%     5432.500000   23625.327732      1.000000     4.062626
# 75%     7668.750000   31637.028912      1.000000     5.112346
# max    10047.000000  148214.616390      2.000000    15.637981
#
#        distance-parking-target   price-paid  search-time  Avg Utility  \
# count              8670.000000  8670.000000  8670.000000  8670.000000
# mean                -95.767593   -96.797982   172.586736    -0.403235
# std                  19.567315    14.917150   147.894005     0.498308
# min                 -99.000000   -99.000000     1.000000   -13.724474
# ...

# %%
x = all['Income Group']
y = all['Avg Utility']
sns.set_palette(palette='Blues')
ax = sns.barplot(x=x, y=y, data=all, palette = 'Blues')
ax.set_xlabel('Income Group')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
# Out:
# Text(0.5, 1.0, 'Average Utility per Income Group')

# %%
x = all_stats.index
y = all_stats['Avg Utility']
ax = sns.lineplot(x=x, y=y, data=all_stats, palette = 'RdYlBu')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
# Out:
# Text(0.5, 1.0, 'Average Utility per Income Group')

# %%
utility = pd.read_csv('avg_utility.csv')
utility
# Out:
#       High Income  Middle Income  Low Income
# 0       -0.366415      -0.412592   -0.467971
# 1       -0.366415      -0.412592   -0.467971
# 2       -0.366415      -0.412025   -0.470917
# 3       -0.366415      -0.412025   -0.470917
# 4       -0.366415      -0.412025   -0.476264
# ...           ...            ...         ...
# 8838    -0.194395      -0.308809   -0.282074
# 8839    -0.194395      -0.308427   -0.284201
# 8840    -0.194395      -0.305842   -0.286819
# 8841    -0.194395      -0.306671   -0.284778
# 8842    -0.194395      -0.307228   -0.282695
#
# [8843 rows x 3 columns]

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
ax = sns.lineplot(data=utility, palette = 'Blues')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
# Out:
# Text(0.5, 1.0, 'Average Utility per Income Group')

# %%
lots = pd.read_csv('lot_distribution.csv')
lots
# Out:
#        Blue Lot  Yellow Lot  Green Lot  Teal  Lot    Garages  \
# 0     30.434783       31.25  30.263158  30.263158   0.000000
# 1     30.434783       31.25  30.263158  30.263158   0.000000
# 2     30.434783       31.25  30.263158  30.263158   0.000000
# 3     30.434783       31.25  30.263158  30.263158   0.000000
# 4     30.434783       31.25  30.263158  30.263158   0.000000
# ...         ...         ...        ...        ...        ...
# 8838  45.652174       43.75  57.894737  52.631579  70.634921
# 8839  45.652174       43.75  57.894737  52.631579  70.634921
# 8840  45.652174       43.75  57.894737  52.631579  70.634921
# 8841  45.652174       43.75  57.894737  52.631579  70.634921
# 8842  45.652174       43.75  57.894737  52.631579  70.634921
#
#       Overall Occupancy
# 0             30.434783
# 1             30.434783
# 2             30.434783
# 3             30.434783
# 4             30.434783
# ...                 ...
# 8838          50.724638
# 8839          50.724638
# ...

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
ax = sns.lineplot(data=lots, palette='pastel')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Lot Distrbution')
ax.set_title('Utilized Capacity of Different Lots')
# Out:
# Text(0.5, 1.0, 'Utilized Capacity of Different Lots')

# %%
strategy = pd.read_csv('strategy.csv')
strategy
# Out:
#       Same Place Parking  Private Parking  Parking After Reaching  \
# 0                    137               44                      51
# 1                    137               44                      51
# 2                    137               45                      52
# 3                    137               45                      52
# 4                    138               45                      52
# ...                  ...              ...                     ...
# 8838                 103               33                      59
# 8839                 102               33                      59
# 8840                 102               32                      59
# 8841                 101               32                      59
# 8842                 101               32                      59
#
#       Nearest Goal Parking  Active Search Parking  Uninformed Nearest Parking  \
# 0                       71                     29                         127
# ...

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
plt.figure(figsize=(20,8))
ax = sns.lineplot(data=strategy, palette='pastel')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Strategy Distrbution')
ax.set_title('Strategies Agents are Following')
# Out:
# Text(0.5, 1.0, 'Strategies Agents are Following')
