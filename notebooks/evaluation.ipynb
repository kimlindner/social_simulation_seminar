# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
old_capacity = pd.read_csv('../social_simulation_seminar/reports/old_model/capacity_cleaned.csv')
old_capacity
# Out:
#        Blue Lot  Yellow Lot  Green Lot   Teal Lot    Garages  \
# 0     40.740741   42.307692  40.425532  40.740741   0.000000
# 1     40.740741   42.307692  40.425532  40.740741   0.000000
# 2     40.740741   42.307692  40.425532  40.740741   0.000000
# 3     40.740741   42.307692  40.425532  40.740741   0.000000
# 4     40.740741   42.307692  40.425532  40.740741   0.000000
# ...         ...         ...        ...        ...        ...
# 8488  40.740741   15.384615  24.468085  37.037037  46.825397
# 8489  40.740741   15.384615  24.468085  37.037037  46.825397
# 8490  40.740741   15.384615  24.468085  37.037037  46.825397
# 8491  40.740741   15.384615  24.468085  37.037037  46.825397
# 8492  40.740741   15.384615  24.468085  37.037037  46.825397
#
#       Overall Occupancy
# 0             40.773810
# 1             40.773810
# 2             40.773810
# 3             40.773810
# 4             40.773810
# ...                 ...
# 8488          33.035714
# 8489          33.035714
# ...

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
ax = sns.lineplot(data=old_capacity, palette='pastel')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Utilized Capacity')
ax.set_title('Utilized Capacity of Different Lots')
# Out:
# Text(0.5, 1.0, 'Utilized Capacity of Different Lots')

# %%
capacity_600 = pd.read_csv('../social_simulation_seminar/reports/600cars/capacity_lots_cleaned.csv')
capacity_600
# Out:
#        Blue Lot  Yellow Lot  Green Lot   Teal Lot    Garages  \
# 0     40.000000   40.384615  40.243902  40.697674   0.000000
# 1     40.000000   40.384615  40.243902  40.697674   0.000000
# 2     40.000000   40.384615  40.243902  40.697674   0.000000
# 3     40.000000   40.384615  40.243902  40.697674   0.000000
# 4     40.000000   40.384615  40.243902  40.697674   0.000000
# ...         ...         ...        ...        ...        ...
# 8210  60.833333   13.461538  39.024390  37.209302  88.095238
# 8211  60.833333   13.461538  39.024390  37.209302  88.095238
# 8212  60.833333   13.461538  39.024390  37.209302  88.095238
# 8213  60.833333   13.461538  39.024390  37.209302  88.095238
# 8214  60.833333   13.461538  39.024390  37.209302  88.095238
#
#       Overall Occupancy
# 0             40.294118
# 1             40.294118
# 2             40.294118
# 3             40.294118
# 4             40.294118
# ...                 ...
# 8210          42.352941
# 8211          42.352941
# ...

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
ax = sns.lineplot(data=capacity_600, palette='pastel')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Utilized Capacity')
ax.set_title('Utilized Capacity of Different Lots')
# Out:
# Text(0.5, 1.0, 'Utilized Capacity of Different Lots')

# %%
capacity_300 = pd.read_csv('../social_simulation_seminar/reports/300cars/capacityLots_cleaned.csv')
capacity_300
# Out:
#        Blue Lot  Yellow Lot  Green Lot   Teal Lot    Garages  \
# 0     40.178571   44.444444  40.740741  40.000000   0.000000
# 1     40.178571   44.444444  40.740741  40.000000   0.000000
# 2     40.178571   44.444444  40.740741  40.000000   0.000000
# 3     40.178571   44.444444  40.740741  40.000000   0.000000
# 4     40.178571   44.444444  40.740741  40.000000   0.000000
# ...         ...         ...        ...        ...        ...
# 8032  36.607143   22.222222  29.629630  37.777778  61.111111
# 8033  36.607143   22.222222  29.629630  37.777778  61.111111
# 8034  36.607143   22.222222  29.629630  37.777778  61.111111
# 8035  36.607143   22.222222  29.629630  37.777778  61.111111
# 8036  36.607143   22.222222  29.629630  37.777778  61.111111
#
#       Overall Occupancy
# 0             40.510949
# 1             40.510949
# 2             40.510949
# 3             40.510949
# 4             40.510949
# ...                 ...
# 8032          34.671533
# 8033          34.671533
# ...

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
ax = sns.lineplot(data=capacity_300, palette='pastel')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Utilized Capacity')
ax.set_title('Utilized Capacity of Different Lots')
# Out:
# Text(0.5, 1.0, 'Utilized Capacity of Different Lots')

# %%
old_model = pd.read_csv('../social_simulation_seminar/models/old_model.csv')
old_model
# Out:
#         id        income  income-group       wtp  parking-offender?  \
# 0     1126  14540.955344             0  3.162375               True
# 1     1041  16647.666552             0  4.201977               True
# 2      893  46946.496269             1  5.255317               True
# 3     1136   8603.495927             0  3.792012              False
# 4     1101   9106.549597             0  4.981238              False
# ...    ...           ...           ...       ...                ...
# 6451  7497  18740.219378             1  6.891680              False
# 6452  7585  13599.027273             0  3.455707               True
# 6453  7362  27844.905601             1  4.416553              False
# 6454  7438  25591.067715             1  4.698974               True
# 6455  7444  24474.154322             1  4.976671              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
parking_cars_old = old_model[(old_model['wants-to-park']== True) & (old_model['price-paid']!= -99)]
parking_cars_old.mean()
# Out:
# /var/folders/xm/3tzqhgxn68n9fnpcrsmf1h880000gn/T/ipykernel_4615/3229103020.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   parking_cars_old.mean()
# id                          2284.253012
# income                     27060.157265
# income-group                   0.891566
# wtp                            5.250848
# parking-offender?              0.156627
# distance-parking-target       20.724450
# price-paid                     3.671687
# search-time                  804.457831
# wants-to-park                  1.000000
# reinitialize?                  1.000000
# dtype: float64

# %%
data_500 = pd.read_csv('../social_simulation_seminar/models/test_2.csv')
data_500
# Out:
#          id        income  income-group       wtp  parking-offender?  \
# 0      1156  20137.004475             1  3.606679              False
# 1      1010  14367.173755             0  2.307360               True
# 2       906  20950.343515             1  3.624336              False
# 3      1170  17685.062598             1  3.883471              False
# 4      1206  14031.965779             0  2.720036              False
# ...     ...           ...           ...       ...                ...
# 8713   9927  18352.567834             1  5.248420              False
# 8714   9762  43925.041642             1  6.135107              False
# 8715  10053  25938.278874             1  4.177520               True
# 8716   9831  23910.822532             1  4.989982               True
# 8717   9879  24907.523760             1  2.953537              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
data_500.min()
# Out:
# id                                885
# income                     3703.51988
# income-group                        0
# wtp                          0.651949
# parking-offender?               False
# distance-parking-target         -99.0
# price-paid                      -99.0
# search-time                         1
# wants-to-park                   False
# die?                             True
# reinitialize?                    True
# utility-value              -13.724474
# mean-utility                -0.424796
# informed-flag                       0
# agent-strategy-flag                 1
# wait-time                           0
# park-time                   129.34964
# switch-strategy-flag                0
# dtype: object

# %%
data_500.max()
# Out:
# id                                10096
# income                     148214.61639
# income-group                          2
# wtp                           15.637981
# parking-offender?                  True
# distance-parking-target       59.464275
# price-paid                         10.0
# search-time                        1456
# wants-to-park                      True
# die?                               True
# reinitialize?                      True
# utility-value                  0.440875
# mean-utility                  -0.243955
# informed-flag                         2
# agent-strategy-flag                   7
# wait-time                             2
# park-time                    43599.3199
# switch-strategy-flag                  1
# dtype: object

# %%
data_500.groupby('income-group').mean('search-time')
# Out:
#                        id        income       wtp  parking-offender?  \
# income-group
# 0             5457.950440  13712.380113  2.488710           0.251042
# 1             5504.557038  27850.651478  4.531449           0.250936
# 2             4967.166667  58183.470412  7.933693           0.258454
#
#               distance-parking-target  price-paid  search-time  wants-to-park  \
# income-group
# 0                          -96.651992  -97.615679   170.042612       0.019453
# 1                          -95.491291  -96.564972   172.835151       0.029129
# 2                          -94.472991  -95.265700   183.896135       0.038647
#
#               die?  reinitialize?  utility-value  mean-utility  informed-flag  \
# income-group
# 0              1.0            1.0      -0.424403     -0.298472       0.997221
# 1              1.0            1.0      -0.395146     -0.297686       0.984866
# 2              1.0            1.0      -0.403601     -0.299908       1.038647
#
# ...

# %%
data_500.mean()
# Out:
# id                          5467.495412
# income                     25789.772740
# income-group                   0.799839
# wtp                            4.187134
# parking-offender?              0.251319
# distance-parking-target      -95.730380
# price-paid                   -96.763478
# search-time                  172.668846
# wants-to-park                  0.027185
# die?                           1.000000
# reinitialize?                  1.000000
# utility-value                 -0.402793
# mean-utility                  -0.297986
# informed-flag                  0.990479
# agent-strategy-flag            3.777472
# wait-time                      0.000459
# park-time                   6867.032231
# switch-strategy-flag           0.000115
# dtype: float64

# %%
parked = data_500[(data_500['wants-to-park']==True) & (data_500['price-paid']!= -99) ]
parked.mean()
# Out:
# id                          2259.153439
# income                     28686.234604
# income-group                   0.925926
# wtp                            4.708296
# parking-offender?              0.248677
# distance-parking-target       17.971660
# price-paid                     4.164021
# search-time                  550.317460
# wants-to-park                  1.000000
# die?                           1.000000
# reinitialize?                  1.000000
# utility-value                 -0.145467
# mean-utility                  -0.291775
# informed-flag                  1.015873
# agent-strategy-flag            3.756614
# wait-time                      0.000000
# park-time                   3474.013728
# switch-strategy-flag           0.005291
# dtype: float64

# %%
data_600 = pd.read_csv('../social_simulation_seminar/models/600cars.csv')
data_600
# Out:
#          id        income  income-group       wtp  parking-offender?  \
# 0      1147  18170.098345             1  4.967432              False
# 1      1062  17064.156654             0  2.199608              False
# 2      1002  13747.159988             0  2.727348              False
# 3      1384  19412.015518             1  5.424040               True
# 4      1466  27309.297334             1  3.016882              False
# ...     ...           ...           ...       ...                ...
# 8619   9730  24159.967301             1  4.834731               True
# 8620  10003  35163.823483             1  3.710384               True
# 8621  10094  19267.787146             1  4.049269              False
# 8622   5651  19824.024683             1  3.607174               True
# 8623    892  19307.508393             1  5.057507               True
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
#print(data_600.min())
print(data_600.max())
# Out:
# id                                 10094
# income                     135855.537356
# income-group                           2
# wtp                            13.199998
# parking-offender?                   True
# distance-parking-target        62.481997
# price-paid                          10.0
# search-time                         2033
# wants-to-park                       True
# die?                                True
# reinitialize?                       True
# utility-value                    0.32376
# mean-utility                   -0.230613
# informed-flag                        2.0
# agent-strategy-flag                  7.0
# wait-time                            2.0
# park-time                   60766.651461
# switch-strategy-flag                 0.0
# dtype: object

# %%
data_600.median()
# Out:
# id                          5448.500000
# income                     23125.161111
# income-group                   1.000000
# wtp                            4.003202
# parking-offender?              0.000000
# distance-parking-target      -99.000000
# price-paid                   -99.000000
# search-time                  156.000000
# wants-to-park                  0.000000
# die?                           1.000000
# reinitialize?                  1.000000
# utility-value                 -0.305913
# mean-utility                  -0.273399
# informed-flag                  1.000000
# agent-strategy-flag            4.000000
# wait-time                      0.000000
# park-time                   5508.172366
# switch-strategy-flag           0.000000
# dtype: float64

# %%
parked_1 = data_600[(data_600['wants-to-park']==True) & (data_600['price-paid']!= -99)]
parked_1.mean()
# Out:
# id                          2558.872832
# income                     28194.879205
# income-group                   0.890173
# wtp                            4.571751
# parking-offender?              0.306358
# distance-parking-target       16.125402
# price-paid                     4.026012
# search-time                  671.867052
# wants-to-park                  1.000000
# die?                           1.000000
# reinitialize?                  1.000000
# utility-value                 -0.134345
# mean-utility                  -0.270830
# informed-flag                  1.092486
# agent-strategy-flag            3.647399
# wait-time                      0.000000
# park-time                   3359.503119
# switch-strategy-flag           0.000000
# dtype: float64

# %%
data_300 = pd.read_csv('../social_simulation_seminar/models/300cars.csv')
data_300
# Out:
#         id        income  income-group       wtp  parking-offender?  \
# 0     1160  22893.428986             1  3.873376              False
# 1      956  22013.841483             1  4.789509              False
# 2     1012  17793.418980             1  3.643025              False
# 3     1003  20072.750520             1  2.840196              False
# 4     1122  12047.797946             0  3.911021               True
# ...    ...           ...           ...       ...                ...
# 5981  7129  22173.951161             1  4.721157              False
# 5982  7086  20584.189844             1  3.475051               True
# 5983  7064  13149.437679             0  2.494514               True
# 5984  7024  10887.556254             0  1.950096              False
# 5985  7055  62540.572419             2  8.541907              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
data_300.mean()
# Out:
# id                          3995.765954
# income                     27237.431910
# income-group                   0.844637
# wtp                            4.289534
# parking-offender?              0.244571
# distance-parking-target      -95.652124
# price-paid                   -97.141873
# search-time                  146.173572
# wants-to-park                  0.027564
# die?                           1.000000
# reinitialize?                  1.000000
# utility-value                 -0.375616
# mean-utility                  -0.295559
# informed-flag                  0.991647
# agent-strategy-flag            3.779151
# wait-time                      0.000000
# park-time                   6873.411242
# switch-strategy-flag           0.000000
# dtype: float64

# %%
parked_2 = data_300[(data_300['wants-to-park']==True) & (data_300['price-paid']!= -99)]
parked_2.mean()
# Out:
# id                          2047.620370
# income                     30437.865614
# income-group                   0.935185
# wtp                            4.834675
# parking-offender?              0.240741
# distance-parking-target       17.002018
# price-paid                     3.988426
# search-time                  368.620370
# wants-to-park                  1.000000
# die?                           1.000000
# reinitialize?                  1.000000
# utility-value                 -0.129624
# mean-utility                  -0.286341
# informed-flag                  0.962963
# agent-strategy-flag            3.731481
# wait-time                      0.000000
# park-time                   3054.133134
# switch-strategy-flag           0.000000
# dtype: float64

# %%
data_300_2 = pd.read_csv('../social_simulation_seminar/models/300cars_min-0.2.csv')
data_300_2
# Out:
#         id        income  income-group       wtp  parking-offender?  \
# 0      902  32191.439122             1  4.350908              False
# 1     1130  10700.919587             0  2.547369              False
# 2      940  32310.087803             1  4.018741              False
# 3     1060  18154.669200             1  4.193936              False
# 4     1003  33371.898980             1  5.443185               True
# ...    ...           ...           ...       ...                ...
# 5831  7003  26043.042105             1  4.125993              False
# 5832  7005  22753.176007             1  4.869892              False
# 5833  6808  53464.688401             2  5.230948               True
# 5834  6874  34555.584292             1  4.006855              False
# 5835  7007  28292.270779             1  5.364198              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
data_300_2.mean()
# Out:
# id                          3920.469157
# income                     26157.109243
# income-group                   0.805517
# wtp                            4.184865
# parking-offender?              0.243831
# distance-parking-target      -95.772817
# price-paid                   -97.531486
# search-time                  148.157814
# wants-to-park                  0.025874
# die?                           1.000000
# reinitialize?                  1.000000
# utility-value                 -0.387803
# mean-utility                  -0.292965
# informed-flag                  1.014393
# agent-strategy-flag            3.782385
# wait-time                      0.000000
# park-time                   6802.246479
# switch-strategy-flag           0.000000
# dtype: float64

# %%
parked_3 = data_300_2[(data_300_2['wants-to-park']==True) & (data_300_2['price-paid']!= -99)]
parked_3.mean()
# Out:
# id                          1918.493976
# income                     26715.734029
# income-group                   0.903614
# wtp                            4.781839
# parking-offender?              0.204819
# distance-parking-target       19.774390
# price-paid                     4.256024
# search-time                  388.156627
# wants-to-park                  1.000000
# die?                           1.000000
# reinitialize?                  1.000000
# utility-value                 -0.142523
# mean-utility                  -0.283720
# informed-flag                  1.132530
# agent-strategy-flag            3.530120
# wait-time                      0.000000
# park-time                   3179.636060
# switch-strategy-flag           0.000000
# dtype: float64

# %%
yellow_lot_300 = pd.read_csv('../social_simulation_seminar/reports/300cars/yellow_lot_cleaned.csv')
yellow_lot_300.dropna()
# Out:
#       High Income  Middle Income  Low Income
# 0               0           62.5        37.5
# 1               0           62.5        37.5
# 2               0           62.5        37.5
# 3               0           62.5        37.5
# 4               0           62.5        37.5
# ...           ...            ...         ...
# 8032           25           25.0        50.0
# 8033           25           25.0        50.0
# 8034           25           25.0        50.0
# 8035           25           25.0        50.0
# 8036           25           25.0        50.0
#
# [8037 rows x 3 columns]

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
ax = sns.lineplot(data=yellow_lot_300, palette='pastel')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Utilized Capacity')
ax.set_title('Utilized Capacity of Yellow Lots per Income Class')
# Out:
# Text(0.5, 1.0, 'Utilized Capacity of Yellow Lots per Income Class')

# %%
old_model_yellow = pd.read_csv('../social_simulation_seminar/reports/old_model/yellowLotShare_cleaned.csv')
old_model_yellow['Low Income'] = old_model_yellow['Low Income;;;;;;;;;;;'].str.strip(';')
old_model_yellow = old_model_yellow.drop(columns='Low Income;;;;;;;;;;;')

# %%
old_model_yellow = old_model_yellow.astype(float)

# %%
new_old = old_model_yellow[old_model_yellow['Low Income']<= 100]
new_old
# Out:
#       High Income  Middle Income  Low Income
# 0       18.181818      63.636364   18.181818
# 1       18.181818      63.636364   18.181818
# 2       18.181818      63.636364   18.181818
# 3       18.181818      63.636364   18.181818
# 4       18.181818      63.636364   18.181818
# ...           ...            ...         ...
# 8439    25.000000      75.000000    0.000000
# 8440    25.000000      75.000000    0.000000
# 8441    25.000000      75.000000    0.000000
# 8442    25.000000      75.000000    0.000000
# 8443    25.000000      75.000000    0.000000
#
# [8227 rows x 3 columns]

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
ax = sns.lineplot(data=new_old, palette='pastel')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Utilized Capacity')
ax.set_title('Utilized Capacity of Yellow Lots per Income Class')
# Out:
# Text(0.5, 1.0, 'Utilized Capacity of Yellow Lots per Income Class')

# %%
yellow_lot_600 = pd.read_csv('../social_simulation_seminar/reports/600cars/share_income_yellowLot.csv')
yellow_lot_600.dropna()
# Out:
#       High Income  Middle Income          Low Income;;;;;;;;;
# 0       19.047619      57.142857  23.809523809523807;;;;;;;;;
# 1       19.047619      57.142857  23.809523809523807;;;;;;;;;
# 2       19.047619      57.142857  23.809523809523807;;;;;;;;;
# 3       19.047619      57.142857  23.809523809523807;;;;;;;;;
# 4       19.047619      57.142857  23.809523809523807;;;;;;;;;
# ...           ...            ...                          ...
# 8210    42.857143      42.857143  14.285714285714285;;;;;;;;;
# 8211    42.857143      42.857143  14.285714285714285;;;;;;;;;
# 8212    42.857143      42.857143  14.285714285714285;;;;;;;;;
# 8213    42.857143      42.857143  14.285714285714285;;;;;;;;;
# 8214    42.857143      42.857143  14.285714285714285;;;;;;;;;
#
# [8215 rows x 3 columns]

# %%
yellow_lot_600['Low Income'] = yellow_lot_600['Low Income;;;;;;;;;'].str.strip(';')
yellow_lot_600 = yellow_lot_600.drop(columns='Low Income;;;;;;;;;')

# %%
yellow_lot_600 = yellow_lot_600.dropna()

# %%
yellow_lot_600 = yellow_lot_600.astype(float)

# %%
yellow_lot_600.max()
# Out:
# High Income         42.857143
# Middle Income       62.500000
# Low Income       44693.000000
# dtype: float64

# %%
new = yellow_lot_600[yellow_lot_600['Low Income'] <= 100]
new
# Out:
#       High Income  Middle Income  Low Income
# 0       19.047619      57.142857   23.809524
# 1       19.047619      57.142857   23.809524
# 2       19.047619      57.142857   23.809524
# 3       19.047619      57.142857   23.809524
# 4       19.047619      57.142857   23.809524
# ...           ...            ...         ...
# 8210    42.857143      42.857143   14.285714
# 8211    42.857143      42.857143   14.285714
# 8212    42.857143      42.857143   14.285714
# 8213    42.857143      42.857143   14.285714
# 8214    42.857143      42.857143   14.285714
#
# [7771 rows x 3 columns]

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
ax = sns.lineplot(data=new, palette='pastel')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Utilized Capacity')
ax.set_title('Utilized Capacity of Yellow Lots per Income Class')
# Out:
# Text(0.5, 1.0, 'Utilized Capacity of Yellow Lots per Income Class')

# %%
#load test csv
stats = pd.read_csv('../social_simulation_seminar/models/test_1.csv')
stats
# Out:
#          id        income  income-group       wtp  parking-offender?  \
# 0      1111  20066.710090             1  4.103842              False
# 1      1209  20949.733322             1  5.155666              False
# 2      1273  26061.313582             1  3.688823              False
# 3      1072  14662.453614             0  3.105921              False
# 4      1374  36403.669318             1  3.693789              False
# ...     ...           ...           ...       ...                ...
# 8765   9925  16499.689924             0  1.912904              False
# 8766  10044   8007.896823             0  1.317967              False
# 8767   9982  45728.092290             1  4.166482              False
# 8768  10099  28316.514499             1  2.110176              False
# 8769   9866   7423.301732             0  1.352993              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
stats.nunique()
# Out:
# id                         8770
# income                     8770
# income-group                  3
# wtp                        8770
# parking-offender?             2
# distance-parking-target     181
# price-paid                   14
# search-time                 700
# wants-to-park                 2
# die?                          1
# reinitialize?                 1
# utility-value              8770
# mean-utility               5577
# informed-flag                 2
# agent-strategy-flag           7
# wait-time                     1
# park-time                  8769
# switch-strategy-flag          3
# dtype: int64

# %%
stats = stats.dropna()

# %%
stats
# Out:
#          id        income  income-group       wtp  parking-offender?  \
# 0      1111  20066.710090             1  4.103842              False
# 1      1209  20949.733322             1  5.155666              False
# 2      1273  26061.313582             1  3.688823              False
# 3      1072  14662.453614             0  3.105921              False
# 4      1374  36403.669318             1  3.693789              False
# ...     ...           ...           ...       ...                ...
# 8764   9940  14133.032261             0  4.133196              False
# 8765   9925  16499.689924             0  1.912904              False
# 8766  10044   8007.896823             0  1.317967              False
# 8767   9982  45728.092290             1  4.166482              False
# 8768  10099  28316.514499             1  2.110176              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
parked = stats[(stats['wants-to-park']==True) & (stats['price-paid']!= -99)]
parked
# Out:
#         id        income  income-group        wtp  parking-offender?  \
# 579    941  17344.991241             0   4.044502              False
# 785   1146  31126.496166             1   7.842640              False
# 828   1148  58899.402229             2  10.434739              False
# 871   1247  25494.973646             1   3.599662               True
# 1174  1194  19114.287121             1   3.863266              False
# ...    ...           ...           ...        ...                ...
# 8701  1137  43096.175981             1   4.307860               True
# 8707  6003  50964.025547             2  10.600620               True
# 8709   928  28238.562736             1   5.696451              False
# 8746   913  27670.204672             1   5.154197              False
# 8762  1326  31348.161225             1   6.309214               True
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
parked.groupby('income-group').mean()
# Out:
#                        id        income       wtp  parking-offender?  \
# income-group
# 0             1953.948718  14154.490717  2.495536           0.179487
# 1             1953.620968  28822.806576  4.750738           0.266129
# 2             2220.000000  59936.190783  8.323896           0.230769
#
#               distance-parking-target  price-paid  search-time  wants-to-park  \
# income-group
# 0                           13.398454    3.641026   684.538462            1.0
# 1                           18.232029    3.669355   541.532258            1.0
# 2                           23.343622    4.115385   509.384615            1.0
#
#               die?  reinitialize?  utility-value  mean-utility  informed-flag  \
# income-group
# 0              1.0            1.0      -0.124568     -0.239121       0.538462
# 1              1.0            1.0      -0.133593     -0.235068       0.532258
# 2              1.0            1.0      -0.112386     -0.236227       0.461538
#
# ...

# %%
stats.groupby(by='income-group').mean('utility-value')
# Out:
#                        id        income       wtp  distance-parking-target  \
# income-group
# 0.0           2338.968519  17278.115924  2.466294               -96.997597
# 1.0           2291.858186  34664.711327  4.517561               -96.641395
# 2.0           2229.471264  69856.093031  7.925942               -99.000000
#
#               price-paid  search-time  utility-value  mean-utility  \
# income-group
# 0.0           -98.064815   194.787037      -0.450350     -0.333203
# 1.0           -97.451156   198.167985      -0.453966     -0.332797
# 2.0           -99.000000   217.689655      -0.436298     -0.336046
#
#               informed-flag  agent-strategy-flag  wait-time    park-time  \
# income-group
# 0.0                0.496296             4.472222   0.000000  6688.894675
# 1.0                0.508825             4.401704   0.002435  6871.454123
# 2.0                0.505747             4.517241   0.000000  6924.545057
#
#               switch-strategy-flag
# income-group
# ...

# %%
ax = sns.barplot(x=x, y=y, data=stats)
ax.set_xlabel('Income Group')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
# Out:
# Text(0.5, 1.0, 'Average Utility per Income Group')

# %%
utility = pd.read_csv('avg_utility_income_class.csv')
utility
# Out:
#          2  High_Utility     1  Mid_Utility     0   Low_Utility
# 0        0     -0.376304     0    -0.431093     0     -0.508641
# 1        1     -0.376304     1    -0.431093     1     -0.508641
# 2        2     -0.376304     2    -0.428960     2     -0.508641
# 3        3     -0.376304     3    -0.428960     3     -0.508641
# 4        4     -0.376304     4    -0.427724     4     -0.508641
# ...    ...           ...   ...          ...   ...           ...
# 2585  2585     -0.276445  2585    -0.288466  2585     -0.383801
# 2586  2586     -0.276445  2586    -0.293044  2586     -0.383801
# 2587  2587     -0.276445  2587    -0.292078  2587     -0.385693
# 2588  2588     -0.276445  2588    -0.292798  2588     -0.387288
# 2589  2589     -0.276445  2589    -0.292507  2589     -0.387288
#
# [2590 rows x 6 columns]

# %%
utility_new = utility.drop(columns=["0","1","2"])

# %%
ax = sns.barplot(data=utility_new)
ax.set_xlabel('Income Group')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
# Out:
# Text(0.5, 1.0, 'Average Utility per Income Group')

# %%
all_stats = pd.read_csv('../social_simulation_seminar/models/test_2.csv')
all_stats
# Out:
#          id        income  income-group       wtp  parking-offender?  \
# 0      1156  20137.004475             1  3.606679              False
# 1      1010  14367.173755             0  2.307360               True
# 2       906  20950.343515             1  3.624336              False
# 3      1170  17685.062598             1  3.883471              False
# 4      1206  14031.965779             0  2.720036              False
# ...     ...           ...           ...       ...                ...
# 8713   9927  18352.567834             1  5.248420              False
# 8714   9762  43925.041642             1  6.135107              False
# 8715  10053  25938.278874             1  4.177520               True
# 8716   9831  23910.822532             1  4.989982               True
# 8717   9879  24907.523760             1  2.953537              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
all_stats = all_stats[(all_stats['wants-to-park']==True) & (all_stats['price-paid']!= -99)]
all_stats
# Out:
#         id        income  income-group       wtp  parking-offender?  \
# 514   1351  24412.474453             1  6.256948               True
# 710   1224  13849.868806             0  4.683243               True
# 799   1211  13932.478173             0  4.129101              False
# 899    937  22246.354073             1  6.150866               True
# 918   1298  14974.620948             0  1.741076               True
# ...    ...           ...           ...       ...                ...
# 8644  1037  23170.204239             1  4.202415              False
# 8681  3829  20323.635788             1  3.402040              False
# 8685  3142  12226.850701             0  4.056305              False
# 8699   942  38313.917790             1  5.420396              False
# 8711  8308  45197.146540             1  3.094834              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
all_stats.describe()
# Out:
#                 id        income  Income Group         wtp  \
# count   185.000000    185.000000    185.000000  185.000000
# mean   2220.318919  28679.117780      0.929730    4.723753
# std    1770.887585  11604.493287      0.478258    1.635653
# min     895.000000   7691.640840      0.000000    1.409719
# 25%    1103.000000  20307.096851      1.000000    3.683239
# 50%    1311.000000  26894.673409      1.000000    4.569494
# 75%    2927.000000  34890.089444      1.000000    5.539963
# max    7757.000000  84249.490832      2.000000    9.760493
#
#        distance-parking-target  price-paid  search-time  Avg Utility  \
# count               185.000000  185.000000   185.000000   185.000000
# mean                 17.908431    4.197297   548.902703    -0.147369
# std                  10.431270    2.194885   280.326908     0.145043
# min                   1.414214    2.000000    21.000000    -0.597308
# 25%                  10.630146    2.000000   343.000000    -0.245141
# ...

# %%
strategy = all_stats.groupby('agent-strategy-flag').mean().reset_index()
strategy = strategy.rename(columns = {'agent-strategy-flag':'Strategy', 'utility-value':'Avg Utility'})
strategy
# Out:
#    Strategy           id        income  income-group       wtp  \
# 0       1.0  2495.113636  30701.452706      1.000000  4.789045
# 1       2.0  1868.000000  25522.232810      0.833333  4.193842
# 2       3.0  2579.200000  28475.627262      0.950000  5.153455
# 3       4.0  2018.150000  28505.290961      0.950000  5.252856
# 4       5.0  2371.733333  28833.072993      1.000000  5.287849
# 5       6.0  1966.733333  28093.283293      0.888889  4.377804
# 6       7.0  2359.764706  29760.416196      0.882353  4.592880
#
#    parking-offender?  distance-parking-target  price-paid  search-time  \
# 0           0.295455                15.935103    4.806818   603.477273
# 1           0.125000                12.281925    5.125000   525.833333
# 2           0.150000                16.161029    4.137500   560.300000
# 3           0.350000                18.183581    4.062500   555.000000
# 4           0.133333                18.697404    3.333333   553.333333
# ...

# %%
x = strategy['Strategy']
y = strategy['Avg Utility']
ax = sns.set_palette(palette='Blues')
ax = sns.barplot(x=x, y=y, data=strategy, palette='Blues')
ax.set_xlabel('Strategy')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Strategy')
# Out:
# Text(0.5, 1.0, 'Average Utility per Strategy')

# %%
income_utility = all_stats.groupby('income-group').mean().reset_index()
income_utility = income_utility.rename(columns = {'income-group':'Income Group', 'utility-value':'Avg Utility'})
income_utility
# Out:
#    Income Group           id        income       wtp  parking-offender?  \
# 0             0  2020.310345  14081.609159  2.836045           0.241379
# 1             1  2280.627586  29076.819568  4.744140           0.255172
# 2             2  2513.333333  53146.189147  7.981483           0.200000
#
#    distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# 0                16.300869    4.060345   578.793103            1.0   1.0
# 1                18.262445    4.194828   545.082759            1.0   1.0
# 2                18.390930    4.066667   545.866667            1.0   1.0
#
#    reinitialize?  Avg Utility  mean-utility  informed-flag  \
# 0            1.0    -0.142493     -0.291808       0.862069
# 1            1.0    -0.149036     -0.291098       1.041379
# 2            1.0    -0.116720     -0.298265       1.066667
#
#    agent-strategy-flag  wait-time    park-time  switch-strategy-flag
# 0             4.068966        0.0  3676.056698              0.000000
# ...

# %%
x = income_utility['Income Group']
y = income_utility['Avg Utility']
sns.set_palette(palette='Blues')
ax = sns.barplot(x=x, y=y, data=income_utility, palette = 'Blues')
ax.set_xlabel('Income Group')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
ax.set(xticklabels=["Low Income", "Middle Income", "High Income"])
# Out:
# [[Text(0, 0, 'Low Income'),
#   Text(1, 0, 'Middle Income'),
#   Text(2, 0, 'High Income')]]

# %%
ax = sns.relplot()
x = income_utility['Income Group']
y = income_utility['Avg Utility']
sns.set_palette(palette='Blues')
ax = sns.barplot(x=x, y=y, data=income_utility, palette = 'Blues')
ax.set_xlabel('Income Group')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
# Out:
#         id        income  income-group       wtp  parking-offender?  \
# 514   1351  24412.474453             1  6.256948               True
# 710   1224  13849.868806             0  4.683243               True
# 799   1211  13932.478173             0  4.129101              False
# 899    937  22246.354073             1  6.150866               True
# 918   1298  14974.620948             0  1.741076               True
# ...    ...           ...           ...       ...                ...
# 8456  5791  47306.442103             2  8.733572              False
# 8467  1332  17475.916266             0  1.438280              False
# 8489  1157  21250.478285             1  5.138065              False
# 8582  1288  11601.984678             0  2.912906              False
# 8644  1037  23170.204239             1  4.202415              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
all_stats = all_stats.rename(columns = {'income-group':'Income Group', 'utility-value':'Avg Utility'})
all_stats
# Out:
#          id        income  Income Group       wtp  parking-offender?  \
# 0      1156  20137.004475             1  3.606679              False
# 1      1010  14367.173755             0  2.307360               True
# 2       906  20950.343515             1  3.624336              False
# 3      1170  17685.062598             1  3.883471              False
# 4      1206  14031.965779             0  2.720036              False
# ...     ...           ...           ...       ...                ...
# 8713   9927  18352.567834             1  5.248420              False
# 8714   9762  43925.041642             1  6.135107              False
# 8715  10053  25938.278874             1  4.177520               True
# 8716   9831  23910.822532             1  4.989982               True
# 8717   9879  24907.523760             1  2.953537              False
#
#       distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# ...

# %%
strategies = all_stats['agent-strategy-flag'].value_counts()
strategies
# Out:
# 1.0    2162
# 6.0    2118
# 4.0    1150
# 3.0    1093
# 7.0     805
# 2.0     775
# 5.0     566
# Name: agent-strategy-flag, dtype: int64

# %%
all = all_stats.groupby('Income Group').mean().reset_index()
all
# Out:
#    Income Group           id        income       wtp  parking-offender?  \
# 0             0  5442.448372  13711.090037  2.488178           0.250698
# 1             1  5479.724251  27843.237561  4.531832           0.251023
# 2             2  4954.966102  58197.717800  7.936101           0.259080
#
#    distance-parking-target  price-paid  search-time  wants-to-park  die?  \
# 0               -96.691960  -97.656860   169.816744       0.019070   1.0
# 1               -95.530457  -96.599844   172.773702       0.028819   1.0
# 2               -94.462030  -95.256659   184.242131       0.038741   1.0
#
#    reinitialize?  Avg Utility  mean-utility  informed-flag  \
# 0            1.0    -0.425243     -0.298497       1.000000
# 1            1.0    -0.395431     -0.297700       0.983625
# 2            1.0    -0.404047     -0.299925       1.041162
#
#    agent-strategy-flag  wait-time    park-time  switch-strategy-flag
# 0             3.772918   0.000000  6944.349020              0.000000
# ...

# %%
all_stats.describe()
# Out:
#                  id         income  Income Group          wtp  \
# count   8670.000000    8670.000000   8670.000000  8670.000000
# mean    5445.483391   25784.677372      0.799654     4.187207
# std     2571.909994   11665.514778      0.505478     1.660785
# min      885.000000    3703.519880      0.000000     0.651949
# 25%     3225.250000   17722.073697      1.000000     3.018168
# 50%     5432.500000   23625.327732      1.000000     4.062626
# 75%     7668.750000   31637.028912      1.000000     5.112346
# max    10047.000000  148214.616390      2.000000    15.637981
#
#        distance-parking-target   price-paid  search-time  Avg Utility  \
# count              8670.000000  8670.000000  8670.000000  8670.000000
# mean                -95.767593   -96.797982   172.586736    -0.403235
# std                  19.567315    14.917150   147.894005     0.498308
# min                 -99.000000   -99.000000     1.000000   -13.724474
# ...

# %%
x = all['Income Group']
y = all['Avg Utility']
sns.set_palette(palette='Blues')
ax = sns.barplot(x=x, y=y, data=all, palette = 'Blues')
ax.set_xlabel('Income Group')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
ax.set(xticklabels=["High Income", "Middle Income", "Low Income"])
# Out:
# Text(0.5, 1.0, 'Average Utility per Income Group')

# %%
x = all_stats.index
y = all_stats['Avg Utility']
ax = sns.lineplot(x=x, y=y, data=all_stats, palette = 'Blues')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Utility')
ax.set_title('Calculated Utility over Time')
# Out:
# Text(0.5, 1.0, 'Calculated Utility over Time')

# %%
utility = pd.read_csv('avg_utility.csv')
utility
# Out:
#       High Income  Middle Income  Low Income
# 0       -0.366415      -0.412592   -0.467971
# 1       -0.366415      -0.412592   -0.467971
# 2       -0.366415      -0.412025   -0.470917
# 3       -0.366415      -0.412025   -0.470917
# 4       -0.366415      -0.412025   -0.476264
# ...           ...            ...         ...
# 8838    -0.194395      -0.308809   -0.282074
# 8839    -0.194395      -0.308427   -0.284201
# 8840    -0.194395      -0.305842   -0.286819
# 8841    -0.194395      -0.306671   -0.284778
# 8842    -0.194395      -0.307228   -0.282695
#
# [8843 rows x 3 columns]

# %%
utility.mean()
# Out:
# High Income     -0.234373
# Middle Income   -0.300134
# Low Income      -0.316759
# dtype: float64

# %%
ax = sns.barplot( data=utility, palette = 'Blues')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
# Out:
# Text(0.5, 1.0, 'Average Utility per Income Group')

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
ax = sns.lineplot(data=utility, palette = 'Blues')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Utility')
ax.set_title('Average Utility per Income Group')
# Out:
# Text(0.5, 1.0, 'Average Utility per Income Group')

# %%
lots = pd.read_csv('lot_distribution.csv')
lots
# Out:
#        Blue Lot  Yellow Lot  Green Lot  Teal  Lot    Garages  \
# 0     30.434783       31.25  30.263158  30.263158   0.000000
# 1     30.434783       31.25  30.263158  30.263158   0.000000
# 2     30.434783       31.25  30.263158  30.263158   0.000000
# 3     30.434783       31.25  30.263158  30.263158   0.000000
# 4     30.434783       31.25  30.263158  30.263158   0.000000
# ...         ...         ...        ...        ...        ...
# 8838  45.652174       43.75  57.894737  52.631579  70.634921
# 8839  45.652174       43.75  57.894737  52.631579  70.634921
# 8840  45.652174       43.75  57.894737  52.631579  70.634921
# 8841  45.652174       43.75  57.894737  52.631579  70.634921
# 8842  45.652174       43.75  57.894737  52.631579  70.634921
#
#       Overall Occupancy
# 0             30.434783
# 1             30.434783
# 2             30.434783
# 3             30.434783
# 4             30.434783
# ...                 ...
# 8838          50.724638
# 8839          50.724638
# ...

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
ax = sns.lineplot(data=lots, palette='pastel')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Lot Distrbution')
ax.set_title('Utilized Capacity of Different Lots')
# Out:
# Text(0.5, 1.0, 'Utilized Capacity of Different Lots')

# %%
strategy = pd.read_csv('strategy.csv')
strategy
# Out:
#       Same Place Parking  Private Parking  Parking After Reaching  \
# 0                    137               44                      51
# 1                    137               44                      51
# 2                    137               45                      52
# 3                    137               45                      52
# 4                    138               45                      52
# ...                  ...              ...                     ...
# 8838                 103               33                      59
# 8839                 102               33                      59
# 8840                 102               32                      59
# 8841                 101               32                      59
# 8842                 101               32                      59
#
#       Nearest Goal Parking  Active Search Parking  Uninformed Nearest Parking  \
# 0                       71                     29                         127
# ...

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
plt.figure(figsize=(20,8))
ax = sns.lineplot(data=strategy, palette='pastel')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Strategy Distrbution')
ax.set_title('Strategies Agents are Following')
# Out:
# Text(0.5, 1.0, 'Strategies Agents are Following')

# %%
old_model = pd.read_csv('initial_model.csv')
old_model
# Out:
#        Blue Lot  Yellow Lot  Green Lot  Teal  Lot    Garages  \
# 0     35.294118        36.0      35.00  35.416667   0.000000
# 1     35.294118        36.0      35.00  35.416667   0.000000
# 2     35.294118        36.0      35.00  35.416667   0.000000
# 3     35.294118        36.0      35.00  35.416667   0.000000
# 4     35.294118        36.0      35.00  35.416667   0.000000
# ...         ...         ...        ...        ...        ...
# 7873  61.764706        18.0      43.75  67.708333  86.507937
# 7874  61.764706        18.0      43.75  67.708333  86.507937
# 7875  61.764706        18.0      43.75  67.708333  86.507937
# 7876  61.764706        18.0      43.75  67.708333  86.507937
# 7877  61.764706        18.0      43.75  67.708333  86.507937
#
#       Overall Occupancy
# 0             35.365854
# 1             35.365854
# 2             35.365854
# 3             35.365854
# 4             35.365854
# ...                 ...
# 7873          52.439024
# 7874          52.439024
# ...

# %%
#x = all_stats.index
#y = all_stats['Avg Utility']
ax = sns.lineplot(data=old_model, palette='pastel')
ax.set_xlabel('Time/Ticks')
ax.set_ylabel('Lot Distrbution')
ax.set_title('Utilized Capacity of Different Lots - Old -')
# Out:
# Text(0.5, 1.0, 'Utilized Capacity of Different Lots - Old -')
